# %% [markdown]
# ## **Sales Prediction with Linear Regression**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.float_format', lambda x: '%.2f' % x)

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split, cross_val_score

# %% [markdown]
# ### **Simple Linear Regression with OLS Using Scikit-Learn**

# %%
df = pd.read_csv("/content/drive/MyDrive/DSMLBC10/week_10 (01.12.22-07.12.22)/machine_learning/datasets/advertising.csv")
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0 230.10  37.80      69.20  22.10
# 1  44.50  39.30      45.10  10.40
# 2  17.20  45.90      69.30   9.30
# 3 151.50  41.30      58.50  18.50
# 4 180.80  10.80      58.40  12.90

# %%
df.shape
# Out:
# (200, 4)

# %%
X = df[["TV"]]
y = df[["sales"]]

# %% [markdown]
# ### **Model**

# %%
reg_model = LinearRegression().fit(X, y)

# y_hat = b + w*TV

# sabit (b - bias)
reg_model.intercept_[0]
# Out:
# 7.032593549127695

# %%
# tv'nin katsayısı (w1)
reg_model.coef_[0][0]
# Out:
# 0.04753664043301975

# %% [markdown]
# ### **Tahmin**

# %%
# 150 birimlik TV harcaması olsa ne kadar satış olması beklenir?

reg_model.intercept_[0] + reg_model.coef_[0][0]*150
# Out:
# 14.163089614080658

# %%
# 500 birimlik tv harcaması olsa ne kadar satış olur?

reg_model.intercept_[0] + reg_model.coef_[0][0]*500
# Out:
# 30.800913765637567

# %%
df.describe().T
# Out:
#            count   mean   std  min   25%    50%    75%    max
# TV        200.00 147.04 85.85 0.70 74.38 149.75 218.82 296.40
# radio     200.00  23.26 14.85 0.00  9.97  22.90  36.52  49.60
# newspaper 200.00  30.55 21.78 0.30 12.75  25.75  45.10 114.00
# sales     200.00  14.02  5.22 1.60 10.38  12.90  17.40  27.00

# %%
# Modelin Görselleştirilmesi
g = sns.regplot(x=X, y=y, scatter_kws={'color': 'b', 's': 9},
                ci=False, color="r")  

# ci : confidence interval

g.set_title(f"Model Denklemi: Sales = {round(reg_model.intercept_[0], 2)} + TV*{round(reg_model.coef_[0][0], 2)}")
g.set_ylabel("Satış Sayısı")
g.set_xlabel("TV Harcamaları")
plt.xlim(-10, 310)
plt.ylim(bottom=0)
plt.show()

# %%
# MSE
y_pred = reg_model.predict(X)
mean_squared_error(y, y_pred)
# Out:
# 10.512652915656757

# %%
print(y.mean())
print(y.std())
# Out:
# sales   14.02
# dtype: float64
# sales   5.22
# dtype: float64

# %% [markdown]
# * MSE 10.51 çıktı. Bu iyi mi kötü mü ? Bunun için bağımlı değişkenin ortalaması ve standart sapmasına bakılarak yorum yapılabilir. Yaklaşık 9-19 arasında değerler değişir. Ortamala 14 iken 10 birim hata yapılıyorsa çok da iyi bir sonuç değildir. Hatta yüksektir denilir.

# %%
# RMSE
np.sqrt(mean_squared_error(y, y_pred))
# Out:
# 3.2423221486546887

# %%
# MAE
mean_absolute_error(y, y_pred)
# Out:
# 2.549806038927486

# %%
# R-KARE
reg_model.score(X, y)
# Out:
# 0.611875050850071

# %% [markdown]
# * R kare bağımsız değişkenlerin, bağımlı değişkeni açıklama yüzdesidir. Yani bu model için bağımsız değişken, bağımlı değişkenin %61'ni açıklamaktadır.

# %% [markdown]
# ### **Multiple Linear Regression**

# %%
df = pd.read_csv("/content/drive/MyDrive/DSMLBC10/week_10 (01.12.22-07.12.22)/machine_learning/datasets/advertising.csv")

X = df.drop('sales', axis=1)
y = df[["sales"]]

# %% [markdown]
# ### **Model**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

y_test.shape

# %20 test, %80 train olacak şekilde veri bölündü
# Out:
# (40, 1)

# %%
y_train.shape
# Out:
# (160, 1)

# %%
reg_model = LinearRegression().fit(X_train, y_train)

# sabit (b - bias)
reg_model.intercept_
# Out:
# array([2.90794702])

# %%
# coefficients (w - weights)
reg_model.coef_
# Out:
# array([[0.0468431 , 0.17854434, 0.00258619]])

# %% [markdown]
# ### **Tahmin**

# %%
# Aşağıdaki gözlem değerlerine göre satışın beklenen değeri nedir?

# TV: 30
# radio: 10
# newspaper: 40

# b = 2.90
# wi = 0.0468431 , 0.17854434, 0.00258619

# Sales = 2.90  + TV * 0.04 + radio * 0.17 + newspaper * 0.002

2.90794702 + 30 * 0.0468431 + 10 * 0.17854434 + 40 * 0.00258619
# Out:
# 6.20213102

# %%
yeni_veri = [[30], [10], [40]]
yeni_veri = pd.DataFrame(yeni_veri).T

# %%
reg_model.predict(yeni_veri)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[6.202131]])

# %% [markdown]
# ### **Tahmin Başarısını Değerlendirme**

# %%
# Train RMSE
y_pred = reg_model.predict(X_train)
np.sqrt(mean_squared_error(y_train, y_pred))
# Out:
# 1.736902590147092

# %%
# Train RKARE
reg_model.score(X_train, y_train)
# Out:
# 0.8959372632325174

# %% [markdown]
# * Tek değişken olduğunda %61 gelmişti, daha fazla değişken ekledik ve bağımsız değişkenlerin bağımlı değişkeni açıklama yüzdesi %89 a çıktı. Hata ise 1.73'e düştü.

# %%
# Test RMSE
y_pred = reg_model.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 1.4113417558581587

# %% [markdown]
# * Normalde test, train hatasından daha yüksek çıkar. Fakat buradaki veri az olduğu için güzel bir senaryodur.

# %%
# Test RKARE
reg_model.score(X_test, y_test)
# Out:
# 0.8927605914615384

# %%
# 10 Katlı CV RMSE
np.mean(np.sqrt(-cross_val_score(reg_model,
                                 X,
                                 y,
                                 cv=10,
                                 scoring="neg_mean_squared_error")))
# Out:
# 1.6913531708051797

# %%
cross_val_score(reg_model, X,  y, cv=10, scoring="neg_mean_squared_error")
# Out:
# array([-3.56038438, -3.29767522, -2.08943356, -2.82474283, -1.3027754 ,
#        -1.74163618, -8.17338214, -2.11409746, -3.04273109, -2.45281793])

# %%
# 5 Katlı CV RMSE
np.mean(np.sqrt(-cross_val_score(reg_model,
                                 X,
                                 y,
                                 cv=5,
                                 scoring="neg_mean_squared_error")))
# Out:
# 1.7175247278732086

# %% [markdown]
# ### **Simple Linear Regression with Gradient Descent from Scratch**

# %%
# Cost function MSE
def cost_function(Y, b, w, X):
    m = len(Y)
    sse = 0

    for i in range(0, m):
        y_hat = b + w * X[i]
        y = Y[i]
        sse += (y_hat - y) ** 2

    mse = sse / m
    return mse

# %%
# update_weights
def update_weights(Y, b, w, X, learning_rate):
    m = len(Y)
    b_deriv_sum = 0
    w_deriv_sum = 0
    for i in range(0, m):
        y_hat = b + w * X[i]
        y = Y[i]
        b_deriv_sum += (y_hat - y)
        w_deriv_sum += (y_hat - y) * X[i]
    new_b = b - (learning_rate * 1 / m * b_deriv_sum)
    new_w = w - (learning_rate * 1 / m * w_deriv_sum)
    return new_b, new_w

# %%
# train fonksiyonu
def train(Y, initial_b, initial_w, X, learning_rate, num_iters):

    print("Starting gradient descent at b = {0}, w = {1}, mse = {2}".format(initial_b, initial_w,
                                                                   cost_function(Y, initial_b, initial_w, X)))

    b = initial_b
    w = initial_w
    cost_history = []

    for i in range(num_iters):
        b, w = update_weights(Y, b, w, X, learning_rate)
        mse = cost_function(Y, b, w, X)
        cost_history.append(mse)


        if i % 100 == 0:
            print("iter={:d}    b={:.2f}    w={:.4f}    mse={:.4}".format(i, b, w, mse))


    print("After {0} iterations b = {1}, w = {2}, mse = {3}".format(num_iters, b, w, cost_function(Y, b, w, X)))
    return cost_history, b, w

# %%
df = pd.read_csv("/content/drive/MyDrive/DSMLBC10/week_10 (01.12.22-07.12.22)/machine_learning/datasets/advertising.csv")

X = df["radio"]
Y = df["sales"]

# hyperparameters
learning_rate = 0.001
initial_b = 0.001
initial_w = 0.001
num_iters = 10000

# %% [markdown]
# * **Parametre :** Modelin veriyi kullanarak, veriden hareketle bulunan değerdir.
#
# * **Hiperparametre :** Veri setinden bulunamayan ve kullanıcı tarafından ayarlanması gereken parametrelerdir.

# %%
cost_history, b, w = train(Y, initial_b, initial_w, X, learning_rate, num_iters)
# Out:
# Starting gradient descent at b = 0.001, w = 0.001, mse = 222.9477491673001
# iter=0    b=0.01    w=0.3708    mse=53.25
# iter=100    b=0.28    w=0.4788    mse=41.6
# iter=200    b=0.54    w=0.4709    mse=40.29
# iter=300    b=0.79    w=0.4633    mse=39.04
# iter=400    b=1.03    w=0.4559    mse=37.87
# iter=500    b=1.27    w=0.4487    mse=36.76
# iter=600    b=1.49    w=0.4417    mse=35.72
# iter=700    b=1.72    w=0.4349    mse=34.73
# iter=800    b=1.93    w=0.4283    mse=33.8
# iter=900    b=2.14    w=0.4219    mse=32.92
# iter=1000    b=2.35    w=0.4157    mse=32.09
# iter=1100    b=2.54    w=0.4096    mse=31.3
# iter=1200    b=2.74    w=0.4037    mse=30.56
# iter=1300    b=2.92    w=0.3980    mse=29.87
# iter=1400    b=3.10    w=0.3925    mse=29.21
# iter=1500    b=3.28    w=0.3871    mse=28.58
# iter=1600    b=3.45    w=0.3818    mse=28.0
# iter=1700    b=3.62    w=0.3767    mse=27.44
# iter=1800    b=3.78    w=0.3718    mse=26.92
# ...
